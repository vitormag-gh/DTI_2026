# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import os
import json
import requests
from tqdm import tqdm
import time
import keras


import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers, models, backend as K
# Out:
# C:\Users\riskf\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\riskf\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
# C:\Users\riskf\anaconda3\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-246-g3d31191b-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# WGAN-GP Architecture
def make_generator_model(input_dim, output_dim):
    model = tf.keras.Sequential()
    model.add(layers.Dense(256, activation='relu', input_dim=input_dim))
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dense(output_dim, activation='linear'))  # Linear activation for WGAN
    return model

def make_critic_model(input_dim):
    model = tf.keras.Sequential()
    model.add(layers.Dense(512, activation='relu', input_dim=input_dim))
    model.add(layers.Dropout(0.1))
    model.add(layers.Dense(256, activation='relu'))
    model.add(layers.Dense(1))  # No activation, linear output
    return model

generator = make_generator_model(100, 101)
critic = make_critic_model(101)

# Losses and training
def critic_loss(real_output, fake_output):
    return tf.reduce_mean(fake_output) - tf.reduce_mean(real_output)

def generator_loss(fake_output):
    return -tf.reduce_mean(fake_output)

def gradient_penalty(batch_size, real_images, fake_images, critic):
    epsilon = tf.random.normal([batch_size, 1], 0.0, 1.0)
    interpolated = epsilon * real_images + (1 - epsilon) * fake_images
    with tf.GradientTape() as tape:
        tape.watch(interpolated)
        pred = critic(interpolated, training=True)
    grads = tape.gradient(pred, [interpolated])[0]
    norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1]))
    gp = tf.reduce_mean((norm - 1.0) ** 2)
    return gp

def train_step(generator, critic, batch_size, generator_optimizer, critic_optimizer, real_features):
    # Append a label column to real_features to match the critic's input expectations
    labels = tf.ones((batch_size, 1))  # Assume label 1 for all positive samples
    real_data = tf.concat([real_features, labels], axis=1)
    
    noise = tf.random.normal([batch_size, generator.input_shape[1]])
    with tf.GradientTape() as gen_tape, tf.GradientTape() as crit_tape:
        generated_data = generator(noise, training=True)

        real_output = critic(real_data, training=True)
        fake_output = critic(generated_data, training=True)

        crit_loss = critic_loss(real_output, fake_output)
        gen_loss = generator_loss(fake_output)
        penalty = gradient_penalty(batch_size, real_data, generated_data, critic)
        crit_loss += 10 * penalty  # lambda for gradient penalty

    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)
    gradients_of_critic = crit_tape.gradient(crit_loss, critic.trainable_variables)

    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))
    critic_optimizer.apply_gradients(zip(gradients_of_critic, critic.trainable_variables))

    return crit_loss, gen_loss

# %%
#relative paths. # Set directory paths for later use.
# Get the directory of the script file
base_dir = os.getcwd()
ligants_type = ['enzyme', 'GPCR', 'ion_channel', 'nuclear_receptor']
ltype = ligants_type[1]
file_name = 'final_new_par_NNMF_50.csv'
file_path = os.path.join(base_dir, 'data', 'split', ltype, file_name)
data_frame = pd.read_csv(file_path, header=None, skiprows=1)
features = data_frame.iloc[:, :-1].values
labels = data_frame.iloc[:, -1].values
# Filter to get only the positive samples
positive_features = features[labels == 1]

# %%
print(positive_features.shape)
print(features.shape)
print(labels.shape)
len(positive_features)
# Out:
# (635, 100)
# (21185, 100)
# (21185,)
# 635

# %%
# Training parameters
num_samples_to_generate = 19915
epochs = 100
batch_size = 256
learning_rate=0.0001
beta_1=0.5
generator_optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1)
critic_optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1)

# Training loop
for epoch in range(epochs):
    for batch in range(0, len(positive_features), batch_size):
        real_data_batch = positive_features[batch:batch + batch_size]
        if real_data_batch.shape[0] != batch_size:  # Handle last batch which may be smaller
            continue  # Skip if the batch isn't full size
        crit_loss, gen_loss = train_step(generator, critic, batch_size, generator_optimizer, critic_optimizer, real_data_batch)
        print(f'Epoch {epoch}, Batch {batch // batch_size}, Critic Loss: {crit_loss.numpy()}, Generator Loss: {gen_loss.numpy()}')
# Out:
# Epoch 0, Batch 0, Critic Loss: 2.481267213821411, Generator Loss: -0.05738067999482155
# Epoch 0, Batch 1, Critic Loss: 2.5392813682556152, Generator Loss: -0.14112913608551025
# Epoch 1, Batch 0, Critic Loss: 2.51015043258667, Generator Loss: -0.22798646986484528
# Epoch 1, Batch 1, Critic Loss: 2.56207275390625, Generator Loss: -0.33638182282447815
# Epoch 2, Batch 0, Critic Loss: 2.424968719482422, Generator Loss: -0.45749056339263916
# Epoch 2, Batch 1, Critic Loss: 2.5199995040893555, Generator Loss: -0.5905004739761353
# Epoch 3, Batch 0, Critic Loss: 2.489124298095703, Generator Loss: -0.7844465374946594
# Epoch 3, Batch 1, Critic Loss: 2.412771701812744, Generator Loss: -0.9533607363700867
# Epoch 4, Batch 0, Critic Loss: 2.459195852279663, Generator Loss: -1.2034063339233398
# Epoch 4, Batch 1, Critic Loss: 2.560898780822754, Generator Loss: -1.4659512042999268
# Epoch 5, Batch 0, Critic Loss: 2.686497688293457, Generator Loss: -1.7751145362854004
# Epoch 5, Batch 1, Critic Loss: 2.8547589778900146, Generator Loss: -2.0890488624572754
# Epoch 6, Batch 0, Critic Loss: 3.0900778770446777, Generator Loss: -2.414132595062256
# Epoch 6, Batch 1, Critic Loss: 3.3370144367218018, Generator Loss: -2.757643938064575
# Epoch 7, Batch 0, Critic Loss: 3.599919319152832, Generator Loss: -3.110761880874634
# Epoch 7, Batch 1, Critic Loss: 3.966442584991455, Generator Loss: -3.450812816619873
# Epoch 8, Batch 0, Critic Loss: 4.278730392456055, Generator Loss: -3.8056819438934326
# Epoch 8, Batch 1, Critic Loss: 4.484012126922607, Generator Loss: -4.043634414672852
# Epoch 9, Batch 0, Critic Loss: 4.769312381744385, Generator Loss: -4.34782600402832
# Epoch 9, Batch 1, Critic Loss: 4.959965705871582, Generator Loss: -4.528088569641113
# Epoch 10, Batch 0, Critic Loss: 5.1538262367248535, Generator Loss: -4.71396541595459
# Epoch 10, Batch 1, Critic Loss: 5.365410804748535, Generator Loss: -4.8585405349731445
# Epoch 11, Batch 0, Critic Loss: 5.472357749938965, Generator Loss: -5.00439977645874
# Epoch 11, Batch 1, Critic Loss: 5.435055732727051, Generator Loss: -4.9851579666137695
# Epoch 12, Batch 0, Critic Loss: 5.313644886016846, Generator Loss: -4.992679119110107
# Epoch 12, Batch 1, Critic Loss: 5.274512767791748, Generator Loss: -4.86995792388916
# Epoch 13, Batch 0, Critic Loss: 5.145476341247559, Generator Loss: -4.8726630210876465
# Epoch 13, Batch 1, Critic Loss: 5.088772296905518, Generator Loss: -4.687682628631592
# Epoch 14, Batch 0, Critic Loss: 4.757667541503906, Generator Loss: -4.455141067504883
# Epoch 14, Batch 1, Critic Loss: 4.62363338470459, Generator Loss: -4.204467296600342
# Epoch 15, Batch 0, Critic Loss: 4.226659297943115, Generator Loss: -3.947343587875366
# Epoch 15, Batch 1, Critic Loss: 4.015593528747559, Generator Loss: -3.6100802421569824
# Epoch 16, Batch 0, Critic Loss: 3.543257236480713, Generator Loss: -3.3023324012756348
# Epoch 16, Batch 1, Critic Loss: 3.3101625442504883, Generator Loss: -2.9269814491271973
# Epoch 17, Batch 0, Critic Loss: 2.998413324356079, Generator Loss: -2.7581324577331543
# Epoch 17, Batch 1, Critic Loss: 2.771693706512451, Generator Loss: -2.4276394844055176
# Epoch 18, Batch 0, Critic Loss: 2.3429481983184814, Generator Loss: -2.209043025970459
# Epoch 18, Batch 1, Critic Loss: 2.2099177837371826, Generator Loss: -2.0251080989837646
# Epoch 19, Batch 0, Critic Loss: 1.883495569229126, Generator Loss: -1.8739529848098755
# Epoch 19, Batch 1, Critic Loss: 1.8650366067886353, Generator Loss: -1.7413448095321655
# Epoch 20, Batch 0, Critic Loss: 1.6586353778839111, Generator Loss: -1.6344058513641357
# Epoch 20, Batch 1, Critic Loss: 1.6689099073410034, Generator Loss: -1.4913418292999268
# Epoch 21, Batch 0, Critic Loss: 1.4039678573608398, Generator Loss: -1.3452590703964233
# Epoch 21, Batch 1, Critic Loss: 1.4240691661834717, Generator Loss: -1.2104045152664185
# Epoch 22, Batch 0, Critic Loss: 1.1822429895401, Generator Loss: -0.9842238426208496
# Epoch 22, Batch 1, Critic Loss: 1.0266108512878418, Generator Loss: -0.6777507066726685
# Epoch 23, Batch 0, Critic Loss: 0.6367523074150085, Generator Loss: -0.3292820453643799
# Epoch 23, Batch 1, Critic Loss: 0.35705769062042236, Generator Loss: 0.07685431838035583
# Epoch 24, Batch 0, Critic Loss: -0.19745469093322754, Generator Loss: 0.5166729688644409
# Epoch 24, Batch 1, Critic Loss: -0.34676772356033325, Generator Loss: 0.8018828630447388
# Epoch 25, Batch 0, Critic Loss: -0.9393783211708069, Generator Loss: 1.2739461660385132
# Epoch 25, Batch 1, Critic Loss: -1.1768749952316284, Generator Loss: 1.6252102851867676
# Epoch 26, Batch 0, Critic Loss: -1.4686791896820068, Generator Loss: 1.7923916578292847
# Epoch 26, Batch 1, Critic Loss: -1.6293811798095703, Generator Loss: 2.0583112239837646
# Epoch 27, Batch 0, Critic Loss: -1.985517144203186, Generator Loss: 2.251908779144287
# Epoch 27, Batch 1, Critic Loss: -2.0242233276367188, Generator Loss: 2.4027676582336426
# Epoch 28, Batch 0, Critic Loss: -2.1131503582000732, Generator Loss: 2.395352840423584
# Epoch 28, Batch 1, Critic Loss: -2.1909677982330322, Generator Loss: 2.584535598754883
# Epoch 29, Batch 0, Critic Loss: -2.3400983810424805, Generator Loss: 2.633488178253174
# Epoch 29, Batch 1, Critic Loss: -2.3090524673461914, Generator Loss: 2.760819435119629
# Epoch 30, Batch 0, Critic Loss: -2.372976541519165, Generator Loss: 2.737124443054199
# Epoch 30, Batch 1, Critic Loss: -2.3526148796081543, Generator Loss: 2.8609042167663574
# Epoch 31, Batch 0, Critic Loss: -2.429537773132324, Generator Loss: 2.9197230339050293
# Epoch 31, Batch 1, Critic Loss: -2.4287664890289307, Generator Loss: 3.093473434448242
# Epoch 32, Batch 0, Critic Loss: -2.615729570388794, Generator Loss: 3.2122912406921387
# Epoch 32, Batch 1, Critic Loss: -2.6430678367614746, Generator Loss: 3.3728322982788086
# Epoch 33, Batch 0, Critic Loss: -2.799420118331909, Generator Loss: 3.4376938343048096
# Epoch 33, Batch 1, Critic Loss: -2.74780535697937, Generator Loss: 3.5178980827331543
# Epoch 34, Batch 0, Critic Loss: -2.841951847076416, Generator Loss: 3.5243048667907715
# Epoch 34, Batch 1, Critic Loss: -2.7145936489105225, Generator Loss: 3.537655830383301
# Epoch 35, Batch 0, Critic Loss: -2.6968746185302734, Generator Loss: 3.4455604553222656
# Epoch 35, Batch 1, Critic Loss: -2.58872389793396, Generator Loss: 3.419708728790283
# Epoch 36, Batch 0, Critic Loss: -2.529787063598633, Generator Loss: 3.2761898040771484
# Epoch 36, Batch 1, Critic Loss: -2.325528383255005, Generator Loss: 3.1996850967407227
# Epoch 37, Batch 0, Critic Loss: -2.236086845397949, Generator Loss: 3.018430709838867
# Epoch 37, Batch 1, Critic Loss: -2.003899097442627, Generator Loss: 2.8841404914855957
# Epoch 38, Batch 0, Critic Loss: -1.8339107036590576, Generator Loss: 2.680875539779663
# Epoch 38, Batch 1, Critic Loss: -1.6107414960861206, Generator Loss: 2.6435060501098633
# Epoch 39, Batch 0, Critic Loss: -1.4581592082977295, Generator Loss: 2.4857380390167236
# Epoch 39, Batch 1, Critic Loss: -1.2972708940505981, Generator Loss: 2.3565406799316406
# Epoch 40, Batch 0, Critic Loss: -1.2101695537567139, Generator Loss: 2.2441153526306152
# Epoch 40, Batch 1, Critic Loss: -1.0176087617874146, Generator Loss: 2.1113193035125732
# Epoch 41, Batch 0, Critic Loss: -0.9292573928833008, Generator Loss: 1.996324896812439
# Epoch 41, Batch 1, Critic Loss: -0.7311686277389526, Generator Loss: 1.9171301126480103
# Epoch 42, Batch 0, Critic Loss: -0.6614992618560791, Generator Loss: 1.8507102727890015
# Epoch 42, Batch 1, Critic Loss: -0.5533671975135803, Generator Loss: 1.7922241687774658
# Epoch 43, Batch 0, Critic Loss: -0.552531361579895, Generator Loss: 1.7672407627105713
# Epoch 43, Batch 1, Critic Loss: -0.48323845863342285, Generator Loss: 1.7473695278167725
# Epoch 44, Batch 0, Critic Loss: -0.4489058256149292, Generator Loss: 1.7447397708892822
# Epoch 44, Batch 1, Critic Loss: -0.30346882343292236, Generator Loss: 1.6783843040466309
# Epoch 45, Batch 0, Critic Loss: -0.3179936408996582, Generator Loss: 1.7102839946746826
# Epoch 45, Batch 1, Critic Loss: -0.2892652750015259, Generator Loss: 1.6772611141204834
# Epoch 46, Batch 0, Critic Loss: -0.4202841520309448, Generator Loss: 1.8137396574020386
# Epoch 46, Batch 1, Critic Loss: -0.47981971502304077, Generator Loss: 1.8623743057250977
# Epoch 47, Batch 0, Critic Loss: -0.5186744928359985, Generator Loss: 1.9193755388259888
# Epoch 47, Batch 1, Critic Loss: -0.6892296075820923, Generator Loss: 2.0204238891601562
# Epoch 48, Batch 0, Critic Loss: -0.7755508422851562, Generator Loss: 2.044858455657959
# Epoch 48, Batch 1, Critic Loss: -0.8713946342468262, Generator Loss: 2.1144802570343018
# Epoch 49, Batch 0, Critic Loss: -0.8298988342285156, Generator Loss: 2.0514156818389893
# Epoch 49, Batch 1, Critic Loss: -0.7751446962356567, Generator Loss: 2.0109262466430664
# Epoch 50, Batch 0, Critic Loss: -0.6986001133918762, Generator Loss: 1.952492117881775
# Epoch 50, Batch 1, Critic Loss: -0.6713316440582275, Generator Loss: 1.9034805297851562
# Epoch 51, Batch 0, Critic Loss: -0.6979022026062012, Generator Loss: 1.9174574613571167
# Epoch 51, Batch 1, Critic Loss: -0.6015505194664001, Generator Loss: 1.8561232089996338
# Epoch 52, Batch 0, Critic Loss: -0.5759337544441223, Generator Loss: 1.8323843479156494
# Epoch 52, Batch 1, Critic Loss: -0.5413241386413574, Generator Loss: 1.7969884872436523
# Epoch 53, Batch 0, Critic Loss: -0.4561648964881897, Generator Loss: 1.7488924264907837
# Epoch 53, Batch 1, Critic Loss: -0.4483282268047333, Generator Loss: 1.6856255531311035
# Epoch 54, Batch 0, Critic Loss: -0.3959130644798279, Generator Loss: 1.6239200830459595
# Epoch 54, Batch 1, Critic Loss: -0.2426309585571289, Generator Loss: 1.4598486423492432
# Epoch 55, Batch 0, Critic Loss: -0.18141663074493408, Generator Loss: 1.4158127307891846
# Epoch 55, Batch 1, Critic Loss: 0.03560793399810791, Generator Loss: 1.2499895095825195
# Epoch 56, Batch 0, Critic Loss: 0.12763434648513794, Generator Loss: 1.1796901226043701
# Epoch 56, Batch 1, Critic Loss: 0.2790943682193756, Generator Loss: 1.1047427654266357
# Epoch 57, Batch 0, Critic Loss: 0.3878159523010254, Generator Loss: 1.0559476613998413
# Epoch 57, Batch 1, Critic Loss: 0.5524263381958008, Generator Loss: 0.9835089445114136
# Epoch 58, Batch 0, Critic Loss: 0.7020511627197266, Generator Loss: 0.930094838142395
# Epoch 58, Batch 1, Critic Loss: 0.7813732028007507, Generator Loss: 0.9409744143486023
# Epoch 59, Batch 0, Critic Loss: 0.7849355936050415, Generator Loss: 0.9635177254676819
# Epoch 59, Batch 1, Critic Loss: 0.8191604614257812, Generator Loss: 0.9617729187011719
# Epoch 60, Batch 0, Critic Loss: 0.7302035093307495, Generator Loss: 1.0468839406967163
# Epoch 60, Batch 1, Critic Loss: 0.7662704586982727, Generator Loss: 1.0706599950790405
# Epoch 61, Batch 0, Critic Loss: 0.698128342628479, Generator Loss: 1.1491674184799194
# Epoch 61, Batch 1, Critic Loss: 0.6362334489822388, Generator Loss: 1.2464302778244019
# Epoch 62, Batch 0, Critic Loss: 0.5227866768836975, Generator Loss: 1.369747281074524
# Epoch 62, Batch 1, Critic Loss: 0.5081743597984314, Generator Loss: 1.4591071605682373
# Epoch 63, Batch 0, Critic Loss: 0.349676251411438, Generator Loss: 1.5988904237747192
# Epoch 63, Batch 1, Critic Loss: 0.25756001472473145, Generator Loss: 1.740962028503418
# Epoch 64, Batch 0, Critic Loss: 0.09536957740783691, Generator Loss: 1.8738291263580322
# Epoch 64, Batch 1, Critic Loss: 0.047531306743621826, Generator Loss: 1.96638822555542
# Epoch 65, Batch 0, Critic Loss: -0.18420755863189697, Generator Loss: 2.1067118644714355
# Epoch 65, Batch 1, Critic Loss: -0.18551141023635864, Generator Loss: 2.167227268218994
# Epoch 66, Batch 0, Critic Loss: -0.301918625831604, Generator Loss: 2.2365846633911133
# Epoch 66, Batch 1, Critic Loss: -0.3145427703857422, Generator Loss: 2.2887537479400635
# Epoch 67, Batch 0, Critic Loss: -0.3659505844116211, Generator Loss: 2.2674567699432373
# Epoch 67, Batch 1, Critic Loss: -0.4015786647796631, Generator Loss: 2.297729969024658
# Epoch 68, Batch 0, Critic Loss: -0.4283851385116577, Generator Loss: 2.276047706604004
# Epoch 68, Batch 1, Critic Loss: -0.3205050230026245, Generator Loss: 2.204221248626709
# Epoch 69, Batch 0, Critic Loss: -0.3612004518508911, Generator Loss: 2.159475326538086
# Epoch 69, Batch 1, Critic Loss: -0.23176664113998413, Generator Loss: 2.1244494915008545
# Epoch 70, Batch 0, Critic Loss: -0.1403728723526001, Generator Loss: 1.9832717180252075
# Epoch 70, Batch 1, Critic Loss: -0.0234261155128479, Generator Loss: 1.937056541442871
# Epoch 71, Batch 0, Critic Loss: 0.040449440479278564, Generator Loss: 1.8558530807495117
# Epoch 71, Batch 1, Critic Loss: 0.1876239776611328, Generator Loss: 1.7573683261871338
# Epoch 72, Batch 0, Critic Loss: 0.181451678276062, Generator Loss: 1.7519676685333252
# Epoch 72, Batch 1, Critic Loss: 0.3884150981903076, Generator Loss: 1.6333307027816772
# Epoch 73, Batch 0, Critic Loss: 0.3977365493774414, Generator Loss: 1.590301275253296
# Epoch 73, Batch 1, Critic Loss: 0.5158406496047974, Generator Loss: 1.536041498184204
# Epoch 74, Batch 0, Critic Loss: 0.5143315196037292, Generator Loss: 1.5126599073410034
# Epoch 74, Batch 1, Critic Loss: 0.6769278049468994, Generator Loss: 1.4352275133132935
# Epoch 75, Batch 0, Critic Loss: 0.6921964287757874, Generator Loss: 1.4012097120285034
# Epoch 75, Batch 1, Critic Loss: 0.7305961847305298, Generator Loss: 1.3834633827209473
# Epoch 76, Batch 0, Critic Loss: 0.6868069767951965, Generator Loss: 1.3568711280822754
# Epoch 76, Batch 1, Critic Loss: 0.8707795143127441, Generator Loss: 1.2914732694625854
# Epoch 77, Batch 0, Critic Loss: 0.868605375289917, Generator Loss: 1.2690961360931396
# Epoch 77, Batch 1, Critic Loss: 0.9375869035720825, Generator Loss: 1.23421311378479
# Epoch 78, Batch 0, Critic Loss: 0.9869219064712524, Generator Loss: 1.1664447784423828
# Epoch 78, Batch 1, Critic Loss: 1.158257007598877, Generator Loss: 1.13944673538208
# Epoch 79, Batch 0, Critic Loss: 1.0215306282043457, Generator Loss: 1.1379225254058838
# Epoch 79, Batch 1, Critic Loss: 1.0767402648925781, Generator Loss: 1.1302480697631836
# Epoch 80, Batch 0, Critic Loss: 1.1330872774124146, Generator Loss: 1.0861694812774658
# Epoch 80, Batch 1, Critic Loss: 1.2056303024291992, Generator Loss: 1.0580791234970093
# Epoch 81, Batch 0, Critic Loss: 1.0914199352264404, Generator Loss: 1.0427953004837036
# Epoch 81, Batch 1, Critic Loss: 1.169703722000122, Generator Loss: 1.0523872375488281
# Epoch 82, Batch 0, Critic Loss: 1.1167426109313965, Generator Loss: 1.0374500751495361
# Epoch 82, Batch 1, Critic Loss: 1.1667734384536743, Generator Loss: 1.0169384479522705
# Epoch 83, Batch 0, Critic Loss: 1.1031564474105835, Generator Loss: 1.0205752849578857
# Epoch 83, Batch 1, Critic Loss: 1.0856938362121582, Generator Loss: 0.9991690516471863
# Epoch 84, Batch 0, Critic Loss: 1.1236356496810913, Generator Loss: 0.9660594463348389
# Epoch 84, Batch 1, Critic Loss: 1.1368725299835205, Generator Loss: 0.9661397933959961
# Epoch 85, Batch 0, Critic Loss: 1.1015137434005737, Generator Loss: 0.9421546459197998
# Epoch 85, Batch 1, Critic Loss: 1.1360986232757568, Generator Loss: 0.9201411008834839
# Epoch 86, Batch 0, Critic Loss: 1.1406036615371704, Generator Loss: 0.8889914751052856
# Epoch 86, Batch 1, Critic Loss: 1.1812955141067505, Generator Loss: 0.8674349784851074
# Epoch 87, Batch 0, Critic Loss: 1.1410995721817017, Generator Loss: 0.8575304746627808
# Epoch 87, Batch 1, Critic Loss: 1.146368145942688, Generator Loss: 0.8309969305992126
# Epoch 88, Batch 0, Critic Loss: 1.1410510540008545, Generator Loss: 0.785438597202301
# Epoch 88, Batch 1, Critic Loss: 1.2465291023254395, Generator Loss: 0.7640701532363892
# Epoch 89, Batch 0, Critic Loss: 1.1962730884552002, Generator Loss: 0.7332853674888611
# Epoch 89, Batch 1, Critic Loss: 1.255185842514038, Generator Loss: 0.7005585432052612
# Epoch 90, Batch 0, Critic Loss: 1.2386407852172852, Generator Loss: 0.6725078821182251
# Epoch 90, Batch 1, Critic Loss: 1.2678333520889282, Generator Loss: 0.645609974861145
# Epoch 91, Batch 0, Critic Loss: 1.2946605682373047, Generator Loss: 0.6279124021530151
# Epoch 91, Batch 1, Critic Loss: 1.2500964403152466, Generator Loss: 0.6066268086433411
# Epoch 92, Batch 0, Critic Loss: 1.2920470237731934, Generator Loss: 0.567787766456604
# Epoch 92, Batch 1, Critic Loss: 1.359537124633789, Generator Loss: 0.5608857870101929
# Epoch 93, Batch 0, Critic Loss: 1.2775566577911377, Generator Loss: 0.540120005607605
# Epoch 93, Batch 1, Critic Loss: 1.3453731536865234, Generator Loss: 0.5315146446228027
# Epoch 94, Batch 0, Critic Loss: 1.3144623041152954, Generator Loss: 0.5219625234603882
# Epoch 94, Batch 1, Critic Loss: 1.394801139831543, Generator Loss: 0.5029410123825073
# Epoch 95, Batch 0, Critic Loss: 1.2786797285079956, Generator Loss: 0.49612510204315186
# Epoch 95, Batch 1, Critic Loss: 1.3740127086639404, Generator Loss: 0.4773081839084625
# Epoch 96, Batch 0, Critic Loss: 1.323354959487915, Generator Loss: 0.4919777512550354
# Epoch 96, Batch 1, Critic Loss: 1.28952157497406, Generator Loss: 0.4756891131401062
# Epoch 97, Batch 0, Critic Loss: 1.2677699327468872, Generator Loss: 0.4839947521686554
# Epoch 97, Batch 1, Critic Loss: 1.3290973901748657, Generator Loss: 0.46788424253463745
# Epoch 98, Batch 0, Critic Loss: 1.3106372356414795, Generator Loss: 0.46462756395339966
# Epoch 98, Batch 1, Critic Loss: 1.329371452331543, Generator Loss: 0.4877927601337433
# Epoch 99, Batch 0, Critic Loss: 1.331176519393921, Generator Loss: 0.47941726446151733
# Epoch 99, Batch 1, Critic Loss: 1.2674808502197266, Generator Loss: 0.48664385080337524

# %%
# Assuming the last column name in  original dataframe represents the label
all_column_names = data_frame.columns.tolist()  # This should have 101 names if the label is included in data_frame

# Generate synthetic data
noise = tf.random.normal([num_samples_to_generate, 100])
synthetic_data = generator(noise, training=False)
synthetic_data_df = pd.DataFrame(synthetic_data.numpy(), columns=all_column_names)
# Set the label for all generated data to 1
synthetic_data_df[all_column_names[-1]] = 1

# %%
#synthetic_data

# %%
# Combine original and synthetic data
enhanced_df = pd.concat([data_frame, synthetic_data_df], axis=0).reset_index(drop=True)
file_name='enhanced_GAN_final_new_par_50_NNFM_space_2.csv'
file_path = os.path.join(base_dir,'data','split',ltype, file_name)
output_path = file_path
enhanced_df.to_csv(output_path, index=False)
